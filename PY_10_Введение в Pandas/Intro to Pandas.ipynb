# %%
import pandas as pd
pd.__version__

countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
display(countries_df)
# Out:
#       country  population      area
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'area'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population      area
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B'])
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
pd.DataFrame([[1, 0], [0, 1]], columns=['А', 'B'])
# Out:
#    А  B
# 0  1  0
# 1  0  1

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
pd.DataFrame({'А': [1, 0], 'B': [0, 1]})
# Out:
#    А  B
# 0  1  0
# 1  0  1

# %%
'''
Вы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.
Доходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.'

#Например:
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

Создайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.

Пример такого DataFrame представлен ниже.

    Income  Expenses
2018    478     156
2019    512     130
2020    196     270
Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.
Примечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.
Примечание. Не забудьте ипортировать библиотеки. '''
# Out:
# "\nВы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.\nДоходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.'\n\n#Например:\nincome = [478, 512, 196]\nexpenses = [156, 130, 270]\nyears = [2018, 2019, 2020]\n\nСоздайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.\n\nПример такого DataFrame представлен ниже.\n\n    Income  Expenses\n2018    478     156\n2019    512     130\n2020    196     270\nТакже напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.\nПримечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.\nПримечание. Не забудьте ипортировать библиотеки. "

# %%
import pandas as pd

def create_companyDF(income, expenses, years):
    data = {
        'Income': income,
        'Expenses': expenses
    }
    df = pd.DataFrame(data, index=years)
    return df

def get_profit(df, year):
    if year in df.index:
        return df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        return None

# Определение переменных
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

# Пример использования
df = create_companyDF(income, expenses, years)
print(df)

profit_2019 = get_profit(df, 2019)
print(f'Чистая прибыль за 2019 год: {profit_2019}')
# Out:
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270
# Чистая прибыль за 2019 год: 382

# %%
import pandas as pd

def create_companyDF(income, expenses, years):
    data = {
        'Income': income,
        'Expenses': expenses
    }
    df = pd.DataFrame(data, index=years)
    return df

def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        profit=None
    return profit

# Определение переменных
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

print(create_companyDF(income = [612, 516, 329, 158], expenses = [136, 163, 250, 361], years = [2017, 2018, 2019, 2020]))
print(get_profit(year = 2018, df = create_companyDF([612, 516, 329, 158], [136,163,250,361], [2017,2018,2019,2020])))
# Out:
#       Income  Expenses
# 2017     612       136
# 2018     516       163
# 2019     329       250
# 2020     158       361
# 353

# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['England', 'Canada', 'USA', 'Russia', 'Ukraine', 'Belarus', 'Kazakhstan'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#       country  population      area
# 0     England       56.29    133396
# 1      Canada       38.05   9984670
# 2         USA      322.28   9826630
# 3      Russia      146.24  17125191
# 4     Ukraine       45.50    603628
# 5     Belarus        9.50    207600
# 6  Kazakhstan       17.04   2724902

# %%
import pandas as pd

melb_data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')

display(melb_data.head(5))
melb_data.tail(7)
melb_data.shape
melb_data.info()
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
melb_data.describe(include=['object'])
melb_data['Type'].value_counts(normalize=True)
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# 0        NaN        Yarra   -37.7996   144.9984  Northern Metropolitan
# 1     1900.0        Yarra   -37.8079   144.9934  Northern Metropolitan
# 2     1900.0        Yarra   -37.8093   144.9944  Northern Metropolitan
# 3        NaN        Yarra   -37.7969   144.9969  Northern Metropolitan
# 4     2014.0        Yarra   -37.8072   144.9941  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# 4         4019.0
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
#  17  CouncilArea    12233 non-null  object
#  18  Lattitude      15064 non-null  float64
#  19  Longtitude     15064 non-null  float64
#  20  Regionname     18395 non-null  object
#  21  Propertycount  18395 non-null  float64
# dtypes: float64(12), int64(2), object(8)
# memory usage: 3.1+ MB
# Type
# h    0.657480
# u    0.233529
# t    0.108991
# Name: proportion, dtype: float64

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')

display(melb_data.loc[1690])
# Out:
# index                             1690
# Suburb                   Carlton North
# Address                  75 Fenwick St
# Rooms                                3
# Type                                 h
# Price                        2050000.0
# Method                               S
# SellerG                         Nelson
# Date                        18/03/2017
# Distance                           3.2
# Postcode                          3054
# Bedroom                            3.0
# Bathroom                           2.0
# Car                                0.0
# Landsize                          84.0
# BuildingArea                     148.0
# YearBuilt                       1970.0
# CouncilArea                      Yarra
# Lattitude                     -37.7879
# Longtitude                    144.9736
# Regionname       Northern Metropolitan
# Propertycount                   3106.0
# Coordinates         -37.7879, 144.9736
# Name: 1690, dtype: object

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')

melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(10), int64(4), object(9)
# memory usage: 2.4+ MB

# %%
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])

print(data.shape)
# Out:
# (3, 2)

# %%
print(melb_data['Price'].mean())
# 1075684.079455081
# Out:
# 1075684.079455081

# %%
print(melb_data['Car'].max())
# 10
# Out:
# 10

# %%
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Total income of real estate agencies: 1752934775.88
# Out:
# Total income of real estate agencies: 1752934775.88

# %%
landsize_median = melb_data['Landsize'].median() 
landsize_mean =  melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# 0.21205713983546193
# Out:
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
# 0    3
# dtype: int64
# Out:
# 0    3
# Name: Rooms, dtype: int64

# %%
melb_data['Regionname'].mode()
# Out:
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
melb_data['Landsize'].std()
# Out:
# 3990.6692411090316

# %%
melb_data['Price'].std()
# Out:
# 639310.724296018

# %%
melb_data['Date'].std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: '3/12/2016'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 melb_data['Date'].std()
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6592, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6583 @doc(make_doc("std", ndim=1))
#    6584 def std(
#    6585     self,
#    (...)
#    6590     **kwargs,
#    6591 ):
# -> 6592     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12358, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12350 def std(
#   12351     self,
#   12352     axis: Axis | None = 0,
#    (...)
#   12356     **kwargs,
#   12357 ) -> Series | float:
# > 12358     return self._stat_function_ddof(
#   12359         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12360     )
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12322, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12319 elif axis is lib.no_default:
#   12320     axis = 0
# > 12322 return self._reduce(
#   12323     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324 )
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: '3/12/2016'

# %%
melb_data['Type'].std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: 'h'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 melb_data['Type'].std()
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6592, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6583 @doc(make_doc("std", ndim=1))
#    6584 def std(
#    6585     self,
#    (...)
#    6590     **kwargs,
#    6591 ):
# -> 6592     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12358, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12350 def std(
#   12351     self,
#   12352     axis: Axis | None = 0,
#    (...)
#   12356     **kwargs,
#   12357 ) -> Series | float:
# > 12358     return self._stat_function_ddof(
#   12359         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12360     )
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12322, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12319 elif axis is lib.no_default:
#   12320     axis = 0
# > 12322 return self._reduce(
#   12323     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324 )
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File c:\Users\Administrator.DESKTOP-8R20EE2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: 'h'

# %%
melb_data['Propertycount'].max()
# Out:
# 21650.0

# %%
a = melb_data['Distance'].std()
print( round(a,0))
# Out:
# 6.0

# %%
a = melb_data['BuildingArea'].median()
b = melb_data['BuildingArea'].mean()
c = abs((a - b) / b)
d = c * 100
print(round(d,0))
# Out:
# 10.0

# %%
from statistics import mode

numbers = [1, 2, 4, 2, 3, 2, 1, 5, 6]

mode_value = mode(numbers)

print(mode_value)
# Out:
# 2

# %%
melb_data['Bedroom'].mode()
# Out:
# 0    3.0
# Name: Bedroom, dtype: float64

# %%
mask = melb_data['Price'] > 2000000
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18391    False
# 18392     True
# 18393    False
# 18394    False
# 18395    False
# Name: Price, Length: 18396, dtype: bool

# %%
display(melb_data[mask].head())
# Out:
#      Unnamed: 0       Suburb               Address  Rooms Type      Price  \
# 119         135  Albert Park  112 Beaconsfield Pde      3    h  2850000.0
# 124         142  Albert Park     104 Richardson St      4    h  2300000.0
# 127         146  Albert Park       114 Victoria Av      3    h  2485000.0
# 128         147  Albert Park        29 Faussett St      2    h  2120000.0
# 132         152  Albert Park           2 Dundas Pl      3    h  2615000.0
#
#     Method   SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 119     PI    Buxton   4/03/2017       3.3  ...       2.0  0.0     211.0
# 124      S  Marshall   7/05/2016       3.3  ...       2.0  1.0     153.0
# 127      S    Cayzer   8/10/2016       3.3  ...       NaN  NaN       NaN
# 128      S      Greg  10/09/2016       3.3  ...       1.0  1.0     199.0
# 132      S    Cayzer  10/12/2016       3.3  ...       2.0  1.0     177.0
#
#      BuildingArea  YearBuilt   CouncilArea  Lattitude Longtitude  \
# 119         198.0     1890.0  Port Phillip   -37.8481   144.9499
# 124         180.0     1880.0  Port Phillip   -37.8447   144.9523
# 127           NaN        NaN           NaN        NaN        NaN
# 128         107.0     1900.0  Port Phillip   -37.8422   144.9554
# 132         181.0     1880.0  Port Phillip   -37.8415   144.9585
#
#                 Regionname  Propertycount
# 119  Southern Metropolitan         3280.0
# 124  Southern Metropolitan         3280.0
# 127  Southern Metropolitan         3280.0
# 128  Southern Metropolitan         3280.0
# 132  Southern Metropolitan         3280.0
#
# [5 rows x 22 columns]

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#        Unnamed: 0           Suburb               Address  Rooms Type  \
# 119           135      Albert Park  112 Beaconsfield Pde      3    h
# 124           142      Albert Park     104 Richardson St      4    h
# 127           146      Albert Park       114 Victoria Av      3    h
# 128           147      Albert Park        29 Faussett St      2    h
# 132           152      Albert Park           2 Dundas Pl      3    h
# ...           ...              ...                   ...    ...  ...
# 18282       23407         Richmond           14 James St      4    h
# 18305       23433  South Melbourne         4 Anderson St      5    h
# 18340       23475     Surrey Hills          20 Albert Cr      4    h
# 18343       23479     Surrey Hills              3 Oak St      4    h
# 18392       23541     Williamstown          96 Verdon St      4    h
#
#            Price Method   SellerG        Date  Distance  ...  Bathroom  Car  \
# 119    2850000.0     PI    Buxton   4/03/2017       3.3  ...       2.0  0.0
# 124    2300000.0      S  Marshall   7/05/2016       3.3  ...       2.0  1.0
# 127    2485000.0      S    Cayzer   8/10/2016       3.3  ...       NaN  NaN
# 128    2120000.0      S      Greg  10/09/2016       3.3  ...       1.0  1.0
# 132    2615000.0      S    Cayzer  10/12/2016       3.3  ...       2.0  1.0
# ...          ...    ...       ...         ...       ...  ...       ...  ...
# 18282  2700000.0      S    Jellis  26/08/2017       2.4  ...       2.0  1.0
# 18305  4500000.0     VB  Marshall  26/08/2017       1.9  ...       3.0  1.0
# 18340  2720000.0      S       Kay  26/08/2017      10.2  ...       3.0  2.0
# 18343  3100000.0     VB  Marshall  26/08/2017      10.2  ...       2.0  3.0
# 18392  2500000.0     PI   Sweeney  26/08/2017       6.8  ...       1.0  5.0
#
#        Landsize  BuildingArea  YearBuilt   CouncilArea  Lattitude Longtitude  \
# 119       211.0         198.0     1890.0  Port Phillip  -37.84810  144.94990
# 124       153.0         180.0     1880.0  Port Phillip  -37.84470  144.95230
# 127         NaN           NaN        NaN           NaN        NaN        NaN
# 128       199.0         107.0     1900.0  Port Phillip  -37.84220  144.95540
# 132       177.0         181.0     1880.0  Port Phillip  -37.84150  144.95850
# ...         ...           ...        ...           ...        ...        ...
# 18282       NaN         252.0     1900.0           NaN  -37.82768  145.00008
# 18305       NaN         179.0     1880.0           NaN  -37.84008  144.95976
# 18340    1005.0           NaN     1920.0           NaN  -37.82421  145.10352
# 18343     832.0           NaN        NaN           NaN  -37.83564  145.10919
# 18392     866.0         157.0     1920.0           NaN  -37.85908  144.89299
#
#                   Regionname  Propertycount
# 119    Southern Metropolitan         3280.0
# 124    Southern Metropolitan         3280.0
# 127    Southern Metropolitan         3280.0
# 128    Southern Metropolitan         3280.0
# 132    Southern Metropolitan         3280.0
# ...                      ...            ...
# 18282  Northern Metropolitan        14949.0
# 18305  Southern Metropolitan         5943.0
# 18340  Southern Metropolitan         5457.0
# 18343  Southern Metropolitan         5457.0
# 18392   Western Metropolitan         6380.0
#
# [1301 rows x 22 columns]

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# 5881
# Out:
# 7953

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# 3
# Out:
# 5

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# 68
# Out:
# 10

# %%
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# 5
# Out:
# 5

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()

# 126.0
# Out:
# 169.0

# %%
melb_data[(melb_data['Bathroom'] == 0)]
# Out:
#        Unnamed: 0           Suburb            Address  Rooms Type      Price  \
# 188           228       Alphington        6 Naroon Rd      3    h  1485000.0
# 381           481         Armadale    3/50 Denbigh Rd      2    u   546000.0
# 679           845        Balaclava     5/11 Albion St      2    u   497500.0
# 791          1009           Balwyn     5 Shrimpton Ct      2    h  1010000.0
# 1223         1549   Bentleigh East    579 Warrigal Rd      3    h   700000.0
# 1402         1772         Brighton          17 New St      3    h  1900000.0
# 1410         1784         Brighton        1/5 Webb St      3    t  1067000.0
# 2107         2716       Camberwell   5 Nicholsdale Rd      4    h  1400000.0
# 2923         3812      Elsternwick    5/29 Nepean Hwy      2    u   410000.0
# 3521         4567        Glen Iris         25 Hope St      2    h   845000.0
# 3546         4611        Glen Iris        130 High St      4    h  1550000.0
# 3558         4637        Glen Iris    1/64 Edgar St N      2    u   545000.0
# 4315         5590          Ivanhoe  5/125 Locksley Rd      2    u   460000.0
# 4516         5827       Kensington      7/51 Epsom Rd      2    u   526000.0
# 4824         6263          Malvern       42 Cressy St      2    h   780000.0
# 6221         8106          Preston       19 Malpas St      4    h  1004000.0
# 7074         9132  South Melbourne          3 Park Pl      1    u   760500.0
# 7196         9280      South Yarra   82/390 Toorak Rd      3    u  1072000.0
# 7278         9389      South Yarra     2/28 Tivoli Pl      2    u   910000.0
# 8169        10485           Toorak   1/183 Kooyong Rd      2    u   857000.0
# 8189        10518           Toorak   6/183 Kooyong Rd      2    u   866000.0
# 8472        10879       Yarraville    1/53 Stephen St      2    u   410000.0
# 8495        10915       Yarraville     1a Kingston St      2    h   610000.0
# 8710        11174   East Melbourne     37/22 Agnes St      2    u   740000.0
# 8723        11193   East Melbourne    9/35 Powlett St      2    u   872000.0
# 8805        11301          Fawkner      1/66 Lorne St      3    u   470000.0
# 9511        12217     Balwyn North   215 Doncaster Rd      3    h  1670000.0
# 10157       13058          Ivanhoe     1/53 Norman St      3    t  1060000.0
# 10501       13515          Preston       86 Malpas St      3    h  1010000.0
# 11581       14870   Caulfield East     5/33 Grange Rd      2    u   350000.0
# 12679       16322         Hawthorn     1/30 Lisson Gr      2    h  1480000.0
# 13785       17718          Preston     24 Mitchell St      3    h  1150000.0
# 13901       17865        Balaclava    9/36 The Avenue      2    u   700000.0
# 14260       18304        St Albans       148 Power St      3    h   702000.0
#
#       Method        SellerG        Date  Distance  ...  Bathroom  Car  \
# 188       SP        McGrath  28/08/2016       6.4  ...       0.0  0.0
# 381       SP  hockingstuart  30/07/2016       6.3  ...       0.0  0.0
# 679       PI  hockingstuart  28/08/2016       6.6  ...       0.0  0.0
# 791       PI       Marshall  30/07/2016       9.7  ...       0.0  0.0
# 1223       S        Thomson  22/05/2016      13.9  ...       0.0  0.0
# 1402       S       Marshall   6/08/2016      11.2  ...       0.0  0.0
# 1410       S            Kay   7/05/2016      11.2  ...       0.0  1.0
# 2107      PI         Jellis  16/04/2016       7.8  ...       0.0  0.0
# 2923      VB           Gary  28/05/2016       8.5  ...       0.0  0.0
# 3521       S           Noel  10/09/2016       9.2  ...       0.0  0.0
# 3546      PI         Jellis  14/05/2016       9.2  ...       0.0  0.0
# 3558       S      Fletchers  16/07/2016       9.2  ...       0.0  0.0
# 4315      VB      Fletchers  16/04/2016       7.9  ...       0.0  0.0
# 4516       S         Nelson  22/08/2016       4.2  ...       0.0  0.0
# 4824      VB         Jellis  14/05/2016       7.4  ...       0.0  0.0
# 6221       S         Nelson   3/09/2016       8.8  ...       0.0  0.0
# 7074       S       Marshall   4/06/2016       2.1  ...       0.0  0.0
# 7196       S            Kay  13/08/2016       3.3  ...       0.0  0.0
# 7278       S       Williams  28/08/2016       3.3  ...       0.0  0.0
# 8169       S          Walsh  22/08/2016       4.6  ...       0.0  0.0
# 8189       S       Marshall  30/07/2016       4.6  ...       0.0  0.0
# 8472      PI  hockingstuart   6/08/2016       7.0  ...       0.0  0.0
# 8495      SP            Jas  15/10/2016       7.0  ...       0.0  0.0
# 8710      SP       Woodards   8/10/2016       1.5  ...       0.0  0.0
# 8723       S         Dingle  28/05/2016       1.5  ...       0.0  0.0
# 8805      SP           Brad  26/07/2016      12.4  ...       0.0  0.0
# 9511       S  hockingstuart  29/04/2017       9.2  ...       0.0  0.0
# 10157      S   Purplebricks  29/04/2017       7.9  ...       0.0  0.0
# 10501     SP        McGrath  20/05/2017       8.8  ...       0.0  0.0
# 11581     SP           Gary   3/06/2017       8.4  ...       0.0  0.0
# 12679      S       Marshall  24/06/2017       5.3  ...       0.0  0.0
# 13785     SP        McGrath   8/07/2017       8.4  ...       0.0  0.0
# 13901     SP       Marshall  12/08/2017       6.4  ...       0.0  0.0
# 14260     SP        Sweeney  12/08/2017      14.0  ...       0.0  0.0
#
#        Landsize  BuildingArea  YearBuilt   CouncilArea  Lattitude Longtitude  \
# 188       597.0           NaN        NaN       Darebin  -37.77810  145.02840
# 381         0.0           NaN        NaN   Stonnington  -37.85680  145.01610
# 679         0.0           NaN        NaN  Port Phillip  -37.87390  144.99290
# 791      1611.0           NaN        NaN    Boroondara  -37.80920  145.10160
# 1223      456.0           NaN        NaN     Glen Eira  -37.93140  145.08080
# 1402        0.0           NaN        NaN       Bayside  -37.93010  144.99350
# 1410        0.0           NaN        NaN       Bayside  -37.91190  144.98710
# 2107      693.0           NaN     1935.0    Boroondara  -37.83600  145.09140
# 2923        0.0           NaN        NaN     Glen Eira  -37.88630  144.99960
# 3521      207.0           NaN        NaN   Stonnington  -37.86300  145.05010
# 3546      769.0           NaN        NaN    Boroondara  -37.86280  145.07340
# 3558        0.0           NaN        NaN   Stonnington  -37.85000  145.04650
# 4315        0.0           NaN        NaN       Banyule  -37.76620  145.05160
# 4516        0.0           NaN        NaN     Melbourne  -37.79190  144.92530
# 4824        0.0           NaN        NaN   Stonnington  -37.85020  145.04180
# 6221      650.0           NaN        NaN       Darebin  -37.73460  145.02260
# 7074      438.0           NaN        NaN  Port Phillip  -37.83530  144.96000
# 7196        0.0           NaN        NaN   Stonnington  -37.84070  145.00430
# 7278        0.0           NaN        NaN     Melbourne  -37.83570  144.98590
# 8169        0.0           NaN        NaN   Stonnington  -37.84580  145.02210
# 8189        0.0           NaN        NaN   Stonnington  -37.84580  145.02210
# 8472        0.0           NaN        NaN   Maribyrnong  -37.81290  144.89520
# 8495       94.0           NaN        NaN   Maribyrnong  -37.81500  144.88270
# 8710        0.0           NaN        NaN     Melbourne  -37.81770  144.98010
# 8723        0.0           NaN        NaN     Melbourne  -37.81540  144.98510
# 8805      261.0           NaN        NaN      Moreland  -37.71580  144.97220
# 9511      818.0           NaN        NaN    Boroondara  -37.79390  145.08660
# 10157     219.0           NaN     1980.0       Banyule  -37.76790  145.04660
# 10501     533.0           NaN        NaN       Darebin  -37.73360  145.01680
# 11581       0.0           NaN        NaN     Glen Eira  -37.88385  145.04785
# 12679     241.0           NaN        NaN    Boroondara  -37.82679  145.03021
# 13785     502.0           NaN        NaN       Darebin  -37.74936  144.98949
# 13901       0.0           NaN        NaN  Port Phillip  -37.87149  144.99746
# 14260     600.0           NaN        NaN      Brimbank  -37.72945  144.79592
#
#                   Regionname  Propertycount
# 188    Northern Metropolitan         2211.0
# 381    Southern Metropolitan         4836.0
# 679    Southern Metropolitan         2952.0
# 791    Southern Metropolitan         5682.0
# 1223   Southern Metropolitan        10969.0
# 1402   Southern Metropolitan        10579.0
# 1410   Southern Metropolitan        10579.0
# 2107   Southern Metropolitan         8920.0
# 2923   Southern Metropolitan         4898.0
# 3521   Southern Metropolitan        10412.0
# 3546   Southern Metropolitan        10412.0
# 3558   Southern Metropolitan        10412.0
# 4315    Eastern Metropolitan         5549.0
# 4516   Northern Metropolitan         5263.0
# 4824   Southern Metropolitan         4675.0
# 6221   Northern Metropolitan        14577.0
# 7074   Southern Metropolitan         5943.0
# 7196   Southern Metropolitan        14887.0
# 7278   Southern Metropolitan        14887.0
# 8169   Southern Metropolitan         7217.0
# 8189   Southern Metropolitan         7217.0
# 8472    Western Metropolitan         6543.0
# 8495    Western Metropolitan         6543.0
# 8710   Northern Metropolitan         3040.0
# 8723   Northern Metropolitan         3040.0
# 8805   Northern Metropolitan         5070.0
# 9511   Southern Metropolitan         7809.0
# 10157   Eastern Metropolitan         5549.0
# 10501  Northern Metropolitan        14577.0
# 11581  Southern Metropolitan          608.0
# 12679  Southern Metropolitan        11308.0
# 13785  Northern Metropolitan        14577.0
# 13901  Southern Metropolitan         2952.0
# 14260   Western Metropolitan        14042.0
#
# [34 rows x 22 columns]

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] >= 3000000)].shape[0]
# 68
# Out:
# 10

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)]
# Out:
#        Unnamed: 0         Suburb            Address  Rooms Type      Price  \
# 3262         4247        Fitzroy         17 Bell St      4    h  4011000.0
# 3290         4281  Fitzroy North    79 Delbridge St      4    h  3400000.0
# 4574         5900            Kew      14 Studley Av      4    h  3700000.0
# 8564        11001     Aberfeldie  126 The Boulevard      4    h  3900000.0
# 9757        12543  Carlton North       235 Amess St      4    h  3450000.0
# 14047       18041        Fitzroy   122 Nicholson St      4    h  3200000.0
# 15658       20068            Kew       35 Miller Gr      4    h  3400000.0
# 16966       21787   Clifton Hill    100 Spensley St      5    h  3900000.0
# 18130       23225   Ivanhoe East      19 Wilfred Rd      5    h  3350000.0
#
#       Method SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 3262       S  Nelson  27/11/2016       1.6  ...       3.0  2.0     286.0
# 3290       S  Nelson  14/05/2016       3.5  ...       2.0  1.0     445.0
# 4574      VB  Nelson   7/05/2016       5.6  ...       NaN  NaN       NaN
# 8564       S  Nelson  10/12/2016       9.1  ...       4.0  4.0     670.0
# 9757       S  Nelson  13/05/2017       3.2  ...       2.0  1.0     515.0
# 14047     VB  Nelson  12/08/2017       2.1  ...       4.0  0.0     225.0
# 15658      S  Nelson   3/09/2017       5.4  ...       2.0  2.0       NaN
# 16966      S  Nelson  19/08/2017       3.6  ...       2.0  0.0       NaN
# 18130     VB  Nelson  26/08/2017       7.8  ...       3.0  2.0       NaN
#
#        BuildingArea  YearBuilt    CouncilArea  Lattitude Longtitude  \
# 3262          275.0     1890.0          Yarra  -37.79990  144.97550
# 3290          175.0     1890.0          Yarra  -37.78600  144.98640
# 4574            NaN        NaN            NaN        NaN        NaN
# 8564          375.0     2010.0  Moonee Valley  -37.76370  144.89310
# 9757          203.0     1905.0          Yarra  -37.78170  144.97420
# 14047           NaN     1862.0          Yarra  -37.80209  144.97443
# 15658           NaN        NaN            NaN  -37.81065  145.02146
# 16966         239.0     1910.0            NaN  -37.78736  145.00091
# 18130         330.0     2010.0            NaN  -37.77496  145.05469
#
#                   Regionname  Propertycount
# 3262   Northern Metropolitan         5825.0
# 3290   Northern Metropolitan         6244.0
# 4574   Southern Metropolitan        10331.0
# 8564    Western Metropolitan         1543.0
# 9757   Northern Metropolitan         3106.0
# 14047  Northern Metropolitan         5825.0
# 15658  Southern Metropolitan        10331.0
# 16966  Northern Metropolitan         2954.0
# 18130   Eastern Metropolitan         1554.0
#
# [9 rows x 22 columns]

# %%
melb_data[(melb_data['Landsize'] == 0)]['Price'].min()
# Out:
# 85000.0

# %%
filtered_data = melb_data[((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015)) & (melb_data['Price'] < 1000000)]
filtered_data['Price'].mean()
# Out:
# 754810.0

# %%
filtered_data = melb_data[(melb_data['Price'] < 3000000) & (melb_data['Type'] == 'h')]

suburb_counts = filtered_data['Suburb'].value_counts()

most_common_suburb = suburb_counts.idxmax()

print(most_common_suburb)
# Out:
# Reservoir
